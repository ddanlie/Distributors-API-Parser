# %%
from enum import Enum

class PropertyType_t(Enum):
    STRING     = str
    NUMBER     = float
    BOOL       = bool
    DICT       = dict
    ENUM       = list[str]
    _UNDEFINED = None


[str == type_.value for type_ in PropertyType_t]
# Out:
# [True, False, False, False, False, False]

# %%
from pathlib import Path

Path("tmp.ipynb").resolve().name
# Out:
# 'tmp.ipynb'

# %%
a = "                             "
if a.startswith(("1", "  ")):
    print("yes")
# Out:
# yes

# %%
for tlvl in range(1, 0, -1):
    print(tlvl)
# Out:
# 1

# %%
x = "adsdsadsadas"
x.split(":")
# Out:
# ['adsdsadsadas']

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path("..").resolve()))

from parser.core.map_engine import _map_engine
from parser.core.constants import CATEGORIES_MAP_FILEPATH

success, result = _map_engine.parse_map_file(CATEGORIES_MAP_FILEPATH)

print(success)
print(result)
# Out:
# True
# [('📦 - Серверы', [], ['asdsd']), ('📺 - Мониторы', [], []), ('🖨 - Принтеры', [], []), ('🧳 - Моноблоки', ['моношмоки'], ['123']), ('моношмоки', [], ['asdsada'])]

# %%
"sdsdadaas asd asd  ".split(":")[0]
# Out:
# 'sdsdadaas asd asd  '
